# %%
from scipy import stats
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from optuna) (21.3)
# Collecting sqlalchemy>=1.3.0 (from optuna)
#   Downloading SQLAlchemy-2.0.32-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.1.2)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 6.8 MB/s eta 0:00:00a 0:00:01
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 32.4 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.32-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.2 MB/s eta 0:00:00:00:01
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 61.3 MB/s eta 0:00:00
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 greenlet-3.0.3 optuna-3.6.1 sqlalchemy-2.0.32

# %%
import optuna

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
L21 = 0.1
L31 = -0.6
L41 = -0.7
L51 = 0
L61 = 0.4
L71 = 0.2
L32 = 0
L42 = -0.1
L52 = 0.4
L62 = 0.1
L72 = 0.1
L43 = 0.2
L53 = -0.4
L63 = 0.6
L73 = 0.01
L54 = 0.4
L64 = 0.1
L74 = -0.3
L65 = 0.3
L75 = 0.5
L76 = 0.2

# %%
L11 = 1

if 1-L21**2 >=0:
    L22 = np.sqrt(1-L21**2)
else:
    raise ValueError('1-L21**2 must be >=0')

if 1-L31**2-L32**2 >=0:
    L33 = np.sqrt(1-L31**2-L32**2)
else:
    raise ValueError('1-L31**2-L32**2 must be >=0')

if 1-L41**2-L42**2-L43**2 >=0:
    L44 = np.sqrt(1-L41**2-L42**2-L43**2)
else:
    raise ValueError('1-L41**2-L42**2-L43**2 must be >=0')

if 1-L51**2-L52**2-L53**2-L54**2 >=0:
    L55 = np.sqrt(1-L51**2-L52**2-L53**2-L54**2)
else:
    raise ValueError('1-L51**2-L52**2-L53**2-L54**2 must be >=0')

if 1-L61**2-L62**2-L63**2-L64**2-L65**2 >=0:
    L66 = np.sqrt(1-L61**2-L62**2-L63**2-L64**2-L65**2)
else:
    raise ValueError('1-L61**2-L62**2-L63**2-L64**2-L65**2 must be >=0')

if 1-L71**2-L72**2-L73**2-L74**2-L75**2-L76**2 >=0:
    L77 = np.sqrt(1-L71**2-L72**2-L73**2-L74**2-L75**2-L76**2)
else:
    raise ValueError('1-L71**2-L72**2-L73**2-L74**2-L75**2-L76**2 must be >=0')

# %%
L = [[L11, 0, 0, 0, 0, 0, 0],
     [L21, L22, 0, 0, 0, 0, 0],
     [L31, L32, L33, 0, 0, 0, 0],
     [L41, L42, L43, L44, 0, 0, 0],
     [L51, L52, L53, L54, L55, 0, 0],
     [L61, L62, L63, L64, L65, L66, 0],
     [L71, L72, L73, L74, L75, L76, L77]]

# %%
covmat_Z = np.dot(L, np.transpose(L))
print(covmat_Z.shape)

# The covariance (=correlation here) matrix must be non-singular and positive semi-definite: verification
if not np.all(np.linalg.eigvals(covmat_Z) >= 0):
    raise ValueError('The covariance matrix is not positive semi-definite')
if round(np.linalg.det(covmat_Z), 6) == 0:
    raise ValueError('The covariance matrix is singular')
# All entries must be in [-1,1]
if not np.all(np.abs(covmat_Z <= 1)):
    raise ValueError('All entries of the correlation matrix must be in [-1,1]')
# Out:
# (7, 7)

# %%
mvnorm = stats.multivariate_normal(mean=np.zeros(covmat_Z.shape[0]), cov=covmat_Z)

m1 = stats.norm(2,0.6)
m2 = stats.norm(0.2,0.3)
m3 = stats.norm(-0.3,2)
m4 = stats.norm(0.7,0.4)
m5 = stats.uniform()
m6 = stats.uniform()
m7 = stats.uniform()

p_a = 0.3
tau_a = 1 - p_a

p_b = 0.9
tau_b = 1-p_b

p_y = 0.2
tau_y = 1 - p_y

# %%
# !mkdir bias_data

datasets=[]
for i in tqdm(range(100)):
    z = mvnorm.rvs(100000)
    u = stats.norm.cdf(z)
    x1 = m1.ppf(u[:, 0])
    x2 = m2.ppf(u[:, 1])
    x3 = m3.ppf(u[:, 2])
    x4 = m4.ppf(u[:, 3])
    x5 = m5.ppf(u[:, 4])
    x6 = m6.ppf(u[:, 5])
    x7 = m7.ppf(u[:, 6])
    a = np.zeros(len(x5), dtype=int)
    a[x5 >= tau_a] = 1
    b = np.zeros(len(x6), dtype=int)
    b[x6 >= tau_b] = 1
    y = np.zeros(len(x7), dtype=int)
    y[x7 >= tau_y] = 1
    data = pd.DataFrame({'X1':x1, 'X2':x2, 'X3':x3, 'X4':x4, 'A':a, 'B':b, 'Y':y})
#     data.to_csv('bias_data/synthetic_data_v2010_' + str(i) + '.csv', index=False)
    datasets.append(data)
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.70it/s]

# %%
datasets[0]
# Out:
#              X1        X2        X3        X4  A  B  Y
# 0      2.469452 -0.420322  0.371305  0.147469  0  1  0
# 1      1.482832  0.217252  1.882589  1.376897  0  1  0
# 2      2.477240 -0.270481  0.437771  0.468329  0  1  1
# 3      1.933746 -0.389778 -2.266573  0.339525  0  1  0
# 4      1.219775  0.573484  1.699252  0.936657  1  1  0
# ...         ...       ...       ...       ... .. .. ..
# 99995  1.642980 -0.034777  0.072811  1.567736  1  1  0
# 99996  2.819471  0.420186 -0.997870  0.322571  0  1  0
# 99997  2.130017  0.070099  0.318068  0.806899  0  1  0
# 99998  2.637568  0.004567  0.766023  0.650571  0  1  0
# 99999  2.159471  0.570677  2.771585  0.603686  0  1  1
#
# [100000 rows x 7 columns]

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[0].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df_train_val, df_test = train_test_split(datasets[0].copy(), test_size=0.2, random_state=42)

df_train, df_val = train_test_split(df_train_val, test_size=0.25, random_state=42)

print(f"Training set: {df_train.shape[0]} samples")
print(f"Validation set: {df_val.shape[0]} samples")
print(f"Test set: {df_test.shape[0]} samples")
# Out:
# Training set: 60000 samples
# Validation set: 20000 samples
# Test set: 20000 samples

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, n_layers, n_units):
        super(Encoder, self).__init__()
        self.layers = []
        for i in range(n_layers):
            if i == 0:
                self.layers.append(nn.Linear(input_dim, n_units))
            else:
                self.layers.append(nn.Linear(n_units, n_units))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.Linear(n_units, input_dim - 2))
        self.model = nn.Sequential(*self.layers)

    def forward(self, x):
        return self.model(x)

# %%
class Predictor(nn.Module):
    def __init__(self, input_dim, n_layers, n_units):
        super(Predictor, self).__init__()
        self.layers = []
        for i in range(n_layers):
            if i == 0:
                self.layers.append(nn.Linear(input_dim, n_units))
            else:
                self.layers.append(nn.Linear(n_units, n_units))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.Linear(n_units, 1))
        self.layers.append(nn.Sigmoid())
        self.model = nn.Sequential(*self.layers)

    def forward(self, x):
        return self.model(x)

# %%
class Adversary(nn.Module):
    def __init__(self, input_dim, n_layers, n_units):
        super(Adversary, self).__init__()
        self.layers = []
        for i in range(n_layers):
            if i == 0:
                self.layers.append(nn.Linear(input_dim, n_units))
            else:
                self.layers.append(nn.Linear(n_units, n_units))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.Linear(n_units, 1))
        self.layers.append(nn.Sigmoid())
        self.model = nn.Sequential(*self.layers)

    def forward(self, x):
        return self.model(x)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe):
        self.X = torch.tensor(dataframe[['X1', 'X2', 'X3', 'X4', 'A', 'B']].values, dtype=torch.float32)
        self.Y = torch.tensor(dataframe[['Y']].values, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]
    
# dataset = CustomDataset(datasets[0])
# dataloader = DataLoader(dataset, batch_size=256, shuffle=True)

# %%
df_train_val, df_test = train_test_split(datasets[0], test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_train_val, test_size=0.25, random_state=42)

# %%
def objective(trial):
    n_layers_enc = trial.suggest_int('n_layers_enc', 1, 3)
    n_units_enc = trial.suggest_int('n_units_enc', 4, 64, step=4)
    n_layers_pred = trial.suggest_int('n_layers_pred', 1, 3)
    n_units_pred = trial.suggest_int('n_units_pred', 4, 64, step=4)
    n_layers_adv = trial.suggest_int('n_layers_adv', 1, 3)
    n_units_adv = trial.suggest_int('n_units_adv', 4, 64, step=4)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    alpha = trial.suggest_float('alpha', 1, 50)
    max_norm = trial.suggest_float('max_norm', 0.1, 5.0)

    encoder = Encoder(6, n_layers_enc, n_units_enc)
    predictor = Predictor(4, n_layers_pred, n_units_pred)
    adversaryA = Adversary(4, n_layers_adv, n_units_adv)
    adversaryB = Adversary(4, n_layers_adv, n_units_adv)

    criterion_enc = nn.MSELoss()
    criterion_pred = nn.BCELoss()
    criterion_advA = nn.BCELoss()
    criterion_advB = nn.BCELoss()

    optimizer_pred = optim.Adam(predictor.parameters(), lr=learning_rate)
    optimizer_advA = optim.Adam(adversaryA.parameters(), lr=learning_rate)
    optimizer_advB = optim.Adam(adversaryB.parameters(), lr=learning_rate)
    optimizer_enc = optim.Adam(encoder.parameters(), lr=learning_rate)

    num_epochs = 200
    encoder.train()
    predictor.train()
    adversaryA.train()
    adversaryB.train()

    dataset = CustomDataset(df_train)
    dataloader = DataLoader(dataset, batch_size=256, shuffle=True)

    for epoch in range(num_epochs):
        for data, labels in dataloader:
            adversaryA.zero_grad()
            adversaryB.zero_grad()
            x_recon = encoder(data)
            adv_predA = adversaryA(x_recon)
            adv_predB = adversaryB(x_recon)
            laA = criterion_advA(adv_predA, data[:, 4].view(-1, 1).float())
            laB = criterion_advB(adv_predB, data[:, 5].view(-1, 1).float())
            laA.backward(retain_graph=True)
            laB.backward()
            torch.nn.utils.clip_grad_norm_(encoder.parameters(), max_norm)
            torch.nn.utils.clip_grad_norm_(predictor.parameters(), max_norm)
            torch.nn.utils.clip_grad_norm_(adversaryA.parameters(), max_norm)
            torch.nn.utils.clip_grad_norm_(adversaryB.parameters(), max_norm)
            optimizer_advA.step()
            optimizer_advB.step()

        for data, labels in dataloader:
            pass
        encoder.zero_grad()
        predictor.zero_grad()
        x_recon = encoder(data)
        y_pred = predictor(x_recon)
        adv_predA = adversaryA(x_recon)
        adv_predB = adversaryB(x_recon)
        lx = criterion_enc(x_recon, data[:, :4])
        lp = criterion_pred(y_pred, labels)
        laA = criterion_advA(adv_predA, data[:, 4].view(-1, 1).float())
        laB = criterion_advB(adv_predB, data[:, 5].view(-1, 1).float())
        combined_loss = lx + lp - (alpha * (laA + laB))
        combined_loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), max_norm)
        torch.nn.utils.clip_grad_norm_(predictor.parameters(), max_norm)
        torch.nn.utils.clip_grad_norm_(adversaryA.parameters(), max_norm)
        torch.nn.utils.clip_grad_norm_(adversaryB.parameters(), max_norm)
        optimizer_pred.step()
        optimizer_enc.step()

    with torch.no_grad():
        val_dataset = CustomDataset(df_val)
        val_dataloader = DataLoader(val_dataset, batch_size=256, shuffle=False)
        total_loss = 0
        for data, labels in val_dataloader:
            x_recon = encoder(data)
            y_pred = predictor(x_recon)
            adv_predA = adversaryA(x_recon)
            adv_predB = adversaryB(x_recon)
            lx = criterion_enc(x_recon, data[:, :4])
            lp = criterion_pred(y_pred, labels)
            laA = criterion_advA(adv_predA, data[:, 4].view(-1, 1).float())
            laB = criterion_advB(adv_predB, data[:, 5].view(-1, 1).float())
            total_loss += lx.item() + lp.item() - (alpha * (laA.item() + laB.item()))
        return total_loss / len(val_dataloader)

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-08-20 21:02:25,417] A new study created in memory with name: no-name-c9e33de0-a68e-4de8-87b4-7f9bea19f896
# [I 2024-08-20 21:08:45,374] Trial 0 finished with value: -14.945119822473016 and parameters: {'n_layers_enc': 3, 'n_units_enc': 20, 'n_layers_pred': 2, 'n_units_pred': 32, 'n_layers_adv': 3, 'n_units_adv': 40, 'learning_rate': 0.005431051234467838, 'alpha': 18.30491299434583, 'max_norm': 4.933686052855412}. Best is trial 0 with value: -14.945119822473016.
# [I 2024-08-20 21:14:22,826] Trial 1 finished with value: -19.181416586096862 and parameters: {'n_layers_enc': 1, 'n_units_enc': 56, 'n_layers_pred': 1, 'n_units_pred': 28, 'n_layers_adv': 2, 'n_units_adv': 56, 'learning_rate': 0.0043480430115644475, 'alpha': 23.319355729493108, 'max_norm': 0.2861913253184043}. Best is trial 1 with value: -19.181416586096862.
# [I 2024-08-20 21:19:14,821] Trial 2 finished with value: -7.888545756308158 and parameters: {'n_layers_enc': 1, 'n_units_enc': 56, 'n_layers_pred': 3, 'n_units_pred': 60, 'n_layers_adv': 1, 'n_units_adv': 8, 'learning_rate': 0.0006855384874157794, 'alpha': 11.048217801452562, 'max_norm': 2.4175907269612504}. Best is trial 1 with value: -19.181416586096862.
# [I 2024-08-20 21:24:24,686] Trial 3 finished with value: -33.18359681047106 and parameters: {'n_layers_enc': 3, 'n_units_enc': 16, 'n_layers_pred': 2, 'n_units_pred': 56, 'n_layers_adv': 1, 'n_units_adv': 12, 'learning_rate': 0.005377935859562724, 'alpha': 37.44865238579191, 'max_norm': 2.099201556911044}. Best is trial 3 with value: -33.18359681047106.
# [I 2024-08-20 21:30:25,992] Trial 4 finished with value: -35.329750550219934 and parameters: {'n_layers_enc': 2, 'n_units_enc': 56, 'n_layers_pred': 2, 'n_units_pred': 12, 'n_layers_adv': 3, 'n_units_adv': 12, 'learning_rate': 0.004012243733539763, 'alpha': 40.44011094774715, 'max_norm': 0.12383202954397073}. Best is trial 4 with value: -35.329750550219934.
# [I 2024-08-20 21:37:05,584] Trial 5 finished with value: -19.777597457675526 and parameters: {'n_layers_enc': 3, 'n_units_enc': 16, 'n_layers_pred': 2, 'n_units_pred': 36, 'n_layers_adv': 3, 'n_units_adv': 64, 'learning_rate': 0.0008640950075017368, 'alpha': 24.933051974060916, 'max_norm': 4.148802496360651}. Best is trial 4 with value: -35.329750550219934.
# [I 2024-08-20 21:42:07,800] Trial 6 finished with value: -30.67561534364609 and parameters: {'n_layers_enc': 2, 'n_units_enc': 28, 'n_layers_pred': 3, 'n_units_pred': 8, 'n_layers_adv': 1, 'n_units_adv': 4, 'learning_rate': 0.00039539366174995595, 'alpha': 35.10641841945033, 'max_norm': 0.7096092333920564}. Best is trial 4 with value: -35.329750550219934.
# [I 2024-08-20 21:48:27,429] Trial 7 finished with value: -17.694057542742662 and parameters: {'n_layers_enc': 2, 'n_units_enc': 20, 'n_layers_pred': 3, 'n_units_pred': 60, 'n_layers_adv': 3, 'n_units_adv': 52, 'learning_rate': 0.00046724611680323396, 'alpha': 28.459548788521825, 'max_norm': 4.421242746388167}. Best is trial 4 with value: -35.329750550219934.
# [I 2024-08-20 21:54:23,294] Trial 8 finished with value: -18.387007059468775 and parameters: {'n_layers_enc': 2, 'n_units_enc': 56, 'n_layers_pred': 3, 'n_units_pred': 20, 'n_layers_adv': 3, 'n_units_adv': 4, 'learning_rate': 0.00012222609659187983, 'alpha': 22.749769067980257, 'max_norm': 3.356461948766569}. Best is trial 4 with value: -35.329750550219934.
# [I 2024-08-20 22:00:11,353] Trial 9 finished with value: -18.307943466839422 and parameters: {'n_layers_enc': 1, 'n_units_enc': 36, 'n_layers_pred': 1, 'n_units_pred': 8, 'n_layers_adv': 3, 'n_units_adv': 24, 'learning_rate': 0.0006458056473126459, 'alpha': 24.50374106884661, 'max_norm': 2.523111125952729}. Best is trial 4 with value: -35.329750550219934.
# [I 2024-08-20 22:05:50,972] Trial 10 finished with value: -42.105397955727156 and parameters: {'n_layers_enc': 2, 'n_units_enc': 44, 'n_layers_pred': 2, 'n_units_pred': 44, 'n_layers_adv': 2, 'n_units_adv': 24, 'learning_rate': 0.002300638337087403, 'alpha': 47.496021023183815, 'max_norm': 1.38821398023327}. Best is trial 10 with value: -42.105397955727156.
# [I 2024-08-20 22:11:28,306] Trial 11 finished with value: -42.05618741016864 and parameters: {'n_layers_enc': 2, 'n_units_enc': 44, 'n_layers_pred': 2, 'n_units_pred': 48, 'n_layers_adv': 2, 'n_units_adv': 24, 'learning_rate': 0.0020172402165989736, 'alpha': 48.15357596193695, 'max_norm': 1.1833835563672022}. Best is trial 10 with value: -42.105397955727156.
# [I 2024-08-20 22:16:59,557] Trial 12 finished with value: -43.190369691909744 and parameters: {'n_layers_enc': 2, 'n_units_enc': 40, 'n_layers_pred': 1, 'n_units_pred': 44, 'n_layers_adv': 2, 'n_units_adv': 24, 'learning_rate': 0.0015530446093544009, 'alpha': 49.818446614917036, 'max_norm': 1.3561247954004334}. Best is trial 12 with value: -43.190369691909744.
# [I 2024-08-20 22:22:28,109] Trial 13 finished with value: -43.26341232608561 and parameters: {'n_layers_enc': 2, 'n_units_enc': 4, 'n_layers_pred': 1, 'n_units_pred': 44, 'n_layers_adv': 2, 'n_units_adv': 28, 'learning_rate': 0.0018167141699764685, 'alpha': 49.47961713556145, 'max_norm': 1.4674437064791832}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 22:27:55,067] Trial 14 finished with value: -41.557479688381484 and parameters: {'n_layers_enc': 2, 'n_units_enc': 4, 'n_layers_pred': 1, 'n_units_pred': 44, 'n_layers_adv': 2, 'n_units_adv': 36, 'learning_rate': 0.0016197681712772968, 'alpha': 49.741338581820806, 'max_norm': 1.6801443652338466}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 22:33:30,189] Trial 15 finished with value: -38.35502086242088 and parameters: {'n_layers_enc': 3, 'n_units_enc': 4, 'n_layers_pred': 1, 'n_units_pred': 52, 'n_layers_adv': 2, 'n_units_adv': 28, 'learning_rate': 0.009943874089016395, 'alpha': 42.37462321707585, 'max_norm': 3.1110701771529103}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 22:38:53,702] Trial 16 finished with value: -21.596046992622778 and parameters: {'n_layers_enc': 1, 'n_units_enc': 36, 'n_layers_pred': 1, 'n_units_pred': 40, 'n_layers_adv': 2, 'n_units_adv': 44, 'learning_rate': 0.00024337734505867708, 'alpha': 32.97685161208972, 'max_norm': 0.8729226349767559}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 22:43:55,037] Trial 17 finished with value: -0.325680590873185 and parameters: {'n_layers_enc': 2, 'n_units_enc': 44, 'n_layers_pred': 1, 'n_units_pred': 24, 'n_layers_adv': 1, 'n_units_adv': 16, 'learning_rate': 0.0013615592824657414, 'alpha': 1.3266279090990523, 'max_norm': 1.8531463147685594}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 22:49:51,917] Trial 18 finished with value: -37.49734425625602 and parameters: {'n_layers_enc': 3, 'n_units_enc': 64, 'n_layers_pred': 1, 'n_units_pred': 64, 'n_layers_adv': 2, 'n_units_adv': 32, 'learning_rate': 0.0011336727315309038, 'alpha': 44.14527560380997, 'max_norm': 3.0475841065376}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 22:55:05,779] Trial 19 finished with value: -27.866730307618255 and parameters: {'n_layers_enc': 1, 'n_units_enc': 32, 'n_layers_pred': 1, 'n_units_pred': 36, 'n_layers_adv': 2, 'n_units_adv': 20, 'learning_rate': 0.003522736218655086, 'alpha': 32.81135566635932, 'max_norm': 0.8299372642201507}. Best is trial 13 with value: -43.26341232608561.
# [I 2024-08-20 23:00:10,217] Trial 20 finished with value: -38.043432136471786 and parameters: {'n_layers_enc': 2, 'n_units_enc': 28, 'n_layers_pred': 1, 'n_units_pred': 52, 'n_layers_adv': 1, 'n_units_adv': 48, 'learning_rate': 0.002485330943511526, 'alpha': 44.07241892890021, 'max_norm': 1.607959630360051}. Best is trial 13 with value: -43.26341232608561.

# %%
print('Best hyperparameters:')
print(study.best_params)
# Print best parameters
print(f'Best trial: {study.best_trial.params}')
print(f'Best value: {study.best_value}')
# Out:
# Best hyperparameters:
# {'n_layers_enc': 2, 'n_units_enc': 24, 'n_layers_pred': 2, 'n_units_pred': 32, 'n_layers_adv': 2, 'n_units_adv': 32, 'learning_rate': 0.006602555051636597, 'alpha': 49.95667523824563, 'max_norm': 2.552031083101195}
# Best trial: {'n_layers_enc': 2, 'n_units_enc': 24, 'n_layers_pred': 2, 'n_units_pred': 32, 'n_layers_adv': 2, 'n_units_adv': 32, 'learning_rate': 0.006602555051636597, 'alpha': 49.95667523824563, 'max_norm': 2.552031083101195}
# Best value: -45.5220802863809

# %%
for a,b in dataloader:
    print(a.shape)
    print(b.shape)
    break
# Out:
# torch.Size([256, 6])
# torch.Size([256, 1])

# %%
num_epochs = 5
encoder.train()

gradient_norms_enc = []
epochs_enc = []

# %%
for epoch in range(num_epochs):

    total_gradient_norm = 0.0
    num_batches = 0

    for data, labels in dataloader: 
        encoder.zero_grad()
        x_recon = encoder(data)
        lx = criterion_enc(x_recon, data[:,:4])
        lx.backward()

        batch_gradient_norm = 0.0
        for p in encoder.parameters():
            if p.grad is not None:
                batch_gradient_norm += p.grad.data.norm(2).item() ** 2
        batch_gradient_norm = batch_gradient_norm ** 0.5
        total_gradient_norm += batch_gradient_norm
        num_batches += 1

        optimizer_enc.step()
    
    average_gradient_norm = total_gradient_norm / num_batches
    gradient_norms_enc.append(average_gradient_norm)
    epochs_enc.append(epoch)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss Recon: {lx.item():.4f}')
# Out:
# Epoch [1/5], Loss Recon: 0.0039
# Epoch [2/5], Loss Recon: 0.0003
# Epoch [3/5], Loss Recon: 0.0001
# Epoch [4/5], Loss Recon: 0.0000
# Epoch [5/5], Loss Recon: 0.0000

# %%
gradient_norms_enc
# Out:
# [0.41592138277618,
#  0.012199086007103049,
#  0.0036769176916042045,
#  0.001619835536264081,
#  0.000704601372657161]

# %%
plt.plot(epochs_enc, gradient_norms_enc, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
# index = 0
# df_original = datasets[index].copy()

# dataset = CustomDataset(df_original)
# dataloader = DataLoader(dataset, batch_size=256, shuffle=True)

# encoder_outputs = []
# encoder.eval()
# with torch.no_grad():
#     for batch_X, _ in dataloader:
#         output = encoder(batch_X)
#         encoder_outputs.append(output)
# encoder_outputs = torch.cat(encoder_outputs, dim=0)

# encoder_outputs_np = encoder_outputs.numpy()
# df = pd.DataFrame(encoder_outputs_np, columns=['X1', 'X2', 'X3', 'X4'])

# df_A_B = df_original[['A', 'B', 'Y']].reset_index(drop=True)
# df = pd.concat([df, df_A_B], axis=1)

# correlation_matrix = df.corr()

# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
# plt.title('Pearson Correlation Heatmap')
# plt.show()

# %%
index = 0
df = pd.DataFrame(encoder(torch.tensor(datasets[index][['X1','X2','X3','X4','A','B']].values, dtype=torch.float32)).detach().numpy(), columns=['X1', 'X2', 'X3', 'X4'])
df_A_B_Y = datasets[index].copy()[['A', 'B', 'Y']].reset_index(drop=True)
df = pd.concat([df, df_A_B_Y], axis=1)
correlation_matrix = df.corr()
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[index].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
num_epochs = 30
predictor.train()

gradient_norms_pred = []
epochs_pred = []

# %%
for epoch in range(num_epochs):

    total_gradient_norm = 0.0
    num_batches = 0

    for data, labels in dataloader: 
        predictor.zero_grad()
        x_recon = encoder(data)
        y_pred = predictor(x_recon.detach())
        lp = criterion_pred(y_pred, labels)
        lp.backward()
        
        batch_gradient_norm = 0.0
        for p in predictor.parameters():
            if p.grad is not None:
                batch_gradient_norm += p.grad.data.norm(2).item() ** 2
        batch_gradient_norm = batch_gradient_norm ** 0.5
        total_gradient_norm += batch_gradient_norm
        num_batches += 1

        optimizer_pred.step()
    
    average_gradient_norm = total_gradient_norm / num_batches
    gradient_norms_pred.append(average_gradient_norm)
    epochs_pred.append(epoch)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss Pred: {lp.item():.4f}')
# Out:
# Epoch [1/30], Loss Pred: 0.5338
# Epoch [2/30], Loss Pred: 0.4930
# Epoch [3/30], Loss Pred: 0.4398
# Epoch [4/30], Loss Pred: 0.4315
# Epoch [5/30], Loss Pred: 0.5094
# Epoch [6/30], Loss Pred: 0.4955
# Epoch [7/30], Loss Pred: 0.4189
# Epoch [8/30], Loss Pred: 0.4049
# Epoch [9/30], Loss Pred: 0.4074
# Epoch [10/30], Loss Pred: 0.5294
# Epoch [11/30], Loss Pred: 0.4475
# Epoch [12/30], Loss Pred: 0.4687
# Epoch [13/30], Loss Pred: 0.4419
# Epoch [14/30], Loss Pred: 0.5174
# Epoch [15/30], Loss Pred: 0.4661
# Epoch [16/30], Loss Pred: 0.4482
# Epoch [17/30], Loss Pred: 0.5030
# Epoch [18/30], Loss Pred: 0.4195
# Epoch [19/30], Loss Pred: 0.4795
# Epoch [20/30], Loss Pred: 0.4328
# Epoch [21/30], Loss Pred: 0.4421
# Epoch [22/30], Loss Pred: 0.5036
# Epoch [23/30], Loss Pred: 0.4584
# Epoch [24/30], Loss Pred: 0.5113
# Epoch [25/30], Loss Pred: 0.4085
# Epoch [26/30], Loss Pred: 0.4582
# Epoch [27/30], Loss Pred: 0.4408
# Epoch [28/30], Loss Pred: 0.5340
# Epoch [29/30], Loss Pred: 0.4450
# Epoch [30/30], Loss Pred: 0.3563

# %%
plt.plot(list(range(num_epochs)), gradient_norms_pred, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
index = 0
df = pd.DataFrame(encoder(torch.tensor(datasets[index][['X1','X2','X3','X4','A','B']].values, dtype=torch.float32)).detach().numpy(), columns=['X1', 'X2', 'X3', 'X4'])
df_A_B_Y = datasets[index].copy()[['A', 'B', 'Y']].reset_index(drop=True)
df = pd.concat([df, df_A_B_Y], axis=1)
correlation_matrix = df.corr()
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[index].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
num_epochs = 30
adversaryA.train()

gradient_norms_advA = []
epochs_advA = []

# %%
for epoch in range(num_epochs):

    total_gradient_norm = 0.0
    num_batches = 0

    for data, labels in dataloader: 
        adversaryA.zero_grad()
        x_recon = encoder(data)
        adv_predA = adversaryA(x_recon.detach())
        laA = criterion_advA(adv_predA, data[:,4].view(-1,1).float())
        laA.backward()
        
        batch_gradient_norm = 0.0
        for p in adversaryA.parameters():
            if p.grad is not None:
                batch_gradient_norm += p.grad.data.norm(2).item() ** 2
        batch_gradient_norm = batch_gradient_norm ** 0.5
        total_gradient_norm += batch_gradient_norm
        num_batches += 1

        optimizer_advA.step()

    average_gradient_norm = total_gradient_norm / num_batches
    gradient_norms_advA.append(average_gradient_norm)
    epochs_advA.append(epoch)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss Adv A: {laA.item():.4f}')
# Out:
# Epoch [1/30], Loss Adv A: 0.4774
# Epoch [2/30], Loss Adv A: 0.4809
# Epoch [3/30], Loss Adv A: 0.4963
# Epoch [4/30], Loss Adv A: 0.4704
# Epoch [5/30], Loss Adv A: 0.4226
# Epoch [6/30], Loss Adv A: 0.4780
# Epoch [7/30], Loss Adv A: 0.4146
# Epoch [8/30], Loss Adv A: 0.5469
# Epoch [9/30], Loss Adv A: 0.4438
# Epoch [10/30], Loss Adv A: 0.4105
# Epoch [11/30], Loss Adv A: 0.4058
# Epoch [12/30], Loss Adv A: 0.4504
# Epoch [13/30], Loss Adv A: 0.4688
# Epoch [14/30], Loss Adv A: 0.4276
# Epoch [15/30], Loss Adv A: 0.4581
# Epoch [16/30], Loss Adv A: 0.4128
# Epoch [17/30], Loss Adv A: 0.3887
# Epoch [18/30], Loss Adv A: 0.4833
# Epoch [19/30], Loss Adv A: 0.4406
# Epoch [20/30], Loss Adv A: 0.5232
# Epoch [21/30], Loss Adv A: 0.5066
# Epoch [22/30], Loss Adv A: 0.4427
# Epoch [23/30], Loss Adv A: 0.4482
# Epoch [24/30], Loss Adv A: 0.3929
# Epoch [25/30], Loss Adv A: 0.4358
# Epoch [26/30], Loss Adv A: 0.4335
# Epoch [27/30], Loss Adv A: 0.4949
# Epoch [28/30], Loss Adv A: 0.4652
# Epoch [29/30], Loss Adv A: 0.4570
# Epoch [30/30], Loss Adv A: 0.4643

# %%
plt.plot(list(range(num_epochs)), gradient_norms_advA, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
index = 0
df = pd.DataFrame(encoder(torch.tensor(datasets[index][['X1','X2','X3','X4','A','B']].values, dtype=torch.float32)).detach().numpy(), columns=['X1', 'X2', 'X3', 'X4'])
df_A_B_Y = datasets[index].copy()[['A', 'B', 'Y']].reset_index(drop=True)
df = pd.concat([df, df_A_B_Y], axis=1)
correlation_matrix = df.corr()
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[index].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
num_epochs = 30
adversaryB.train()

gradient_norms_advB = []
epochs_advB = []

# %%
for epoch in range(num_epochs):

    total_gradient_norm = 0.0
    num_batches = 0

    for data, labels in dataloader: 
        adversaryB.zero_grad()
        x_recon = encoder(data)
        adv_predB = adversaryB(x_recon.detach())
        laB = criterion_advB(adv_predB, data[:,4].view(-1,1).float())
        laB.backward()
        
        batch_gradient_norm = 0.0
        for p in adversaryB.parameters():
            if p.grad is not None:
                batch_gradient_norm += p.grad.data.norm(2).item() ** 2
        batch_gradient_norm = batch_gradient_norm ** 0.5
        total_gradient_norm += batch_gradient_norm
        num_batches += 1

        optimizer_advB.step()

    average_gradient_norm = total_gradient_norm / num_batches
    gradient_norms_advB.append(average_gradient_norm)
    epochs_advB.append(epoch)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss Adv: {laB.item():.4f}')
# Out:
# Epoch [1/30], Loss Adv: 0.5478
# Epoch [2/30], Loss Adv: 0.4347
# Epoch [3/30], Loss Adv: 0.5194
# Epoch [4/30], Loss Adv: 0.4426
# Epoch [5/30], Loss Adv: 0.4248
# Epoch [6/30], Loss Adv: 0.4821
# Epoch [7/30], Loss Adv: 0.4296
# Epoch [8/30], Loss Adv: 0.4766
# Epoch [9/30], Loss Adv: 0.4433
# Epoch [10/30], Loss Adv: 0.4750
# Epoch [11/30], Loss Adv: 0.4005
# Epoch [12/30], Loss Adv: 0.4518
# Epoch [13/30], Loss Adv: 0.3844
# Epoch [14/30], Loss Adv: 0.4495
# Epoch [15/30], Loss Adv: 0.3287
# Epoch [16/30], Loss Adv: 0.3958
# Epoch [17/30], Loss Adv: 0.5253
# Epoch [18/30], Loss Adv: 0.4822
# Epoch [19/30], Loss Adv: 0.4794
# Epoch [20/30], Loss Adv: 0.4389
# Epoch [21/30], Loss Adv: 0.4238
# Epoch [22/30], Loss Adv: 0.5294
# Epoch [23/30], Loss Adv: 0.4283
# Epoch [24/30], Loss Adv: 0.4545
# Epoch [25/30], Loss Adv: 0.5179
# Epoch [26/30], Loss Adv: 0.4360
# Epoch [27/30], Loss Adv: 0.4353
# Epoch [28/30], Loss Adv: 0.4442
# Epoch [29/30], Loss Adv: 0.4228
# Epoch [30/30], Loss Adv: 0.4566

# %%
plt.plot(list(range(num_epochs)), gradient_norms_advB, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
index = 0
df = pd.DataFrame(encoder(torch.tensor(datasets[index][['X1','X2','X3','X4','A','B']].values, dtype=torch.float32)).detach().numpy(), columns=['X1', 'X2', 'X3', 'X4'])
df_A_B_Y = datasets[index].copy()[['A', 'B', 'Y']].reset_index(drop=True)
df = pd.concat([df, df_A_B_Y], axis=1)
correlation_matrix = df.corr()
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[index].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
num_epochs = 50
encoder.train()
predictor.train()
adversaryA.train()
adversaryB.train()

gradient_norms_advA = []
gradient_norms_advB = []
gradient_norms_enc = []
gradient_norms_pred = []
epochs_total = []

# %%
for epoch in range(num_epochs):
    
    total_gradient_norm_A = 0.0
    total_gradient_norm_B = 0.0
    total_gradient_norm_enc = 0.0
    total_gradient_norm_pred = 0.0
    num_batches_adv = 0
    num_batches_other = 0

    for data, labels in dataloader: 
        adversaryA.zero_grad()
        adversaryB.zero_grad()
        x_recon = encoder(data)
        adv_predA = adversaryA(x_recon)
        adv_predB = adversaryB(x_recon)
        laA = criterion_advA(adv_predA, data[:,4].view(-1,1).float())
        laB = criterion_advB(adv_predB, data[:,5].view(-1,1).float())
        laA.backward(retain_graph=True)
        laB.backward()
        
        batch_gradient_norm_A = 0.0
        for p in adversaryA.parameters():
            if p.grad is not None:
                batch_gradient_norm_A += p.grad.data.norm(2).item() ** 2
        batch_gradient_norm_A = batch_gradient_norm_A ** 0.5
        total_gradient_norm_A += batch_gradient_norm_A

        batch_gradient_norm_B = 0.0
        for p in adversaryB.parameters():
            if p.grad is not None:
                batch_gradient_norm_B += p.grad.data.norm(2).item() ** 2
        batch_gradient_norm_B = batch_gradient_norm_B ** 0.5
        total_gradient_norm_B += batch_gradient_norm_B

        num_batches_adv += 1

        torch.nn.utils.clip_grad_norm_(encoder.parameters(), 1.0)
        torch.nn.utils.clip_grad_norm_(predictor.parameters(), 1.0)
        torch.nn.utils.clip_grad_norm_(adversaryA.parameters(), 1.0)
        torch.nn.utils.clip_grad_norm_(adversaryB.parameters(), 1.0)

        optimizer_advA.step()
        optimizer_advB.step()
        
    for data, labels in dataloader: 
        pass
    
    encoder.zero_grad()
    predictor.zero_grad()
    x_recon = encoder(data)
    y_pred = predictor(x_recon)
    adv_predA = adversaryA(x_recon)
    adv_predB = adversaryB(x_recon)

    lx = criterion_enc(x_recon, data[:,:4])
    lp = criterion_pred(y_pred, labels)
    laA = criterion_advA(adv_predA, data[:,4].view(-1,1).float())
    laB = criterion_advB(adv_predB, data[:,5].view(-1,1).float())
    
    combined_loss = lx + lp - (10 * (laA + laB))
#     combined_loss = lx + lp - (laA + laB)
    combined_loss.backward()

    for p in adversaryA.parameters():
        if p.grad is not None:
            batch_gradient_norm_A += p.grad.data.norm(2).item() ** 2
    batch_gradient_norm_A = batch_gradient_norm_A ** 0.5
    total_gradient_norm_A += batch_gradient_norm_A
    
    for p in adversaryB.parameters():
        if p.grad is not None:
            batch_gradient_norm_B += p.grad.data.norm(2).item() ** 2
    batch_gradient_norm_B = batch_gradient_norm_B ** 0.5
    total_gradient_norm_B += batch_gradient_norm_B

    batch_gradient_norm_enc = 0.0
    for p in encoder.parameters():
        if p.grad is not None:
            batch_gradient_norm_enc += p.grad.data.norm(2).item() ** 2
    batch_gradient_norm_enc = batch_gradient_norm_enc ** 0.5
    total_gradient_norm_enc += batch_gradient_norm_enc

    batch_gradient_norm_pred = 0.0
    for p in predictor.parameters():
        if p.grad is not None:
            batch_gradient_norm_pred += p.grad.data.norm(2).item() ** 2
    batch_gradient_norm_pred = batch_gradient_norm_pred ** 0.5
    total_gradient_norm_pred += batch_gradient_norm_pred


    num_batches_other += 1
    num_batches_adv += 1

    torch.nn.utils.clip_grad_norm_(encoder.parameters(), 1.0)
    torch.nn.utils.clip_grad_norm_(predictor.parameters(), 1.0)
    torch.nn.utils.clip_grad_norm_(adversaryA.parameters(), 1.0)
    torch.nn.utils.clip_grad_norm_(adversaryB.parameters(), 1.0)

    optimizer_pred.step()
    optimizer_enc.step()

    
    average_gradient_norm_A = total_gradient_norm_A / num_batches_adv
    gradient_norms_advA.append(average_gradient_norm_A)

    average_gradient_norm_B = total_gradient_norm_B / num_batches_adv
    gradient_norms_advB.append(average_gradient_norm_B)
    
    average_gradient_norm_enc = total_gradient_norm_enc / num_batches_other
    gradient_norms_enc.append(average_gradient_norm_enc)

    average_gradient_norm_pred = total_gradient_norm_pred / num_batches_other
    gradient_norms_pred.append(average_gradient_norm_pred)

    epochs_total.append(epoch)

#     print("num_batches_adv",num_batches_adv)
#     print("num_batches_other",num_batches_other)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss A: {laA.item():.4f}, Loss B: {laB.item():.4f}, Loss Recon: {lx.item():.4f}, Loss P: {lp.item():.4f}, Loss Comb: {combined_loss.item():.4f}')
# Out:
# Epoch [1/50], Loss A: 0.6150, Loss B: 0.2857, Loss Recon: 0.5035, Loss P: 0.5211, Loss Comb: -7.9823
# Epoch [2/50], Loss A: 0.6158, Loss B: 0.2853, Loss Recon: 0.4727, Loss P: 0.5185, Loss Comb: -8.0196
# Epoch [3/50], Loss A: 0.6163, Loss B: 0.2844, Loss Recon: 0.4423, Loss P: 0.5160, Loss Comb: -8.0484
# Epoch [4/50], Loss A: 0.6165, Loss B: 0.2830, Loss Recon: 0.4130, Loss P: 0.5142, Loss Comb: -8.0672
# Epoch [5/50], Loss A: 0.6163, Loss B: 0.2811, Loss Recon: 0.3855, Loss P: 0.5132, Loss Comb: -8.0752
# Epoch [6/50], Loss A: 0.6157, Loss B: 0.2789, Loss Recon: 0.3604, Loss P: 0.5132, Loss Comb: -8.0729
# Epoch [7/50], Loss A: 0.6150, Loss B: 0.2765, Loss Recon: 0.3382, Loss P: 0.5142, Loss Comb: -8.0628
# Epoch [8/50], Loss A: 0.6145, Loss B: 0.2739, Loss Recon: 0.3191, Loss P: 0.5157, Loss Comb: -8.0491
# Epoch [9/50], Loss A: 0.6143, Loss B: 0.2715, Loss Recon: 0.3030, Loss P: 0.5175, Loss Comb: -8.0373
# Epoch [10/50], Loss A: 0.6145, Loss B: 0.2695, Loss Recon: 0.2896, Loss P: 0.5188, Loss Comb: -8.0317
# Epoch [11/50], Loss A: 0.6151, Loss B: 0.2682, Loss Recon: 0.2783, Loss P: 0.5195, Loss Comb: -8.0348
# Epoch [12/50], Loss A: 0.6158, Loss B: 0.2677, Loss Recon: 0.2686, Loss P: 0.5194, Loss Comb: -8.0472
# Epoch [13/50], Loss A: 0.6165, Loss B: 0.2682, Loss Recon: 0.2602, Loss P: 0.5185, Loss Comb: -8.0682
# Epoch [14/50], Loss A: 0.6170, Loss B: 0.2696, Loss Recon: 0.2531, Loss P: 0.5170, Loss Comb: -8.0965
# Epoch [15/50], Loss A: 0.6174, Loss B: 0.2719, Loss Recon: 0.2471, Loss P: 0.5152, Loss Comb: -8.1298
# Epoch [16/50], Loss A: 0.6175, Loss B: 0.2746, Loss Recon: 0.2422, Loss P: 0.5133, Loss Comb: -8.1660
# Epoch [17/50], Loss A: 0.6176, Loss B: 0.2776, Loss Recon: 0.2383, Loss P: 0.5116, Loss Comb: -8.2023
# Epoch [18/50], Loss A: 0.6177, Loss B: 0.2803, Loss Recon: 0.2351, Loss P: 0.5101, Loss Comb: -8.2353
# Epoch [19/50], Loss A: 0.6176, Loss B: 0.2826, Loss Recon: 0.2319, Loss P: 0.5090, Loss Comb: -8.2614
# Epoch [20/50], Loss A: 0.6172, Loss B: 0.2842, Loss Recon: 0.2281, Loss P: 0.5081, Loss Comb: -8.2779
# Epoch [21/50], Loss A: 0.6162, Loss B: 0.2853, Loss Recon: 0.2232, Loss P: 0.5075, Loss Comb: -8.2843
# Epoch [22/50], Loss A: 0.6146, Loss B: 0.2861, Loss Recon: 0.2169, Loss P: 0.5072, Loss Comb: -8.2832
# Epoch [23/50], Loss A: 0.6129, Loss B: 0.2867, Loss Recon: 0.2094, Loss P: 0.5071, Loss Comb: -8.2794
# Epoch [24/50], Loss A: 0.6115, Loss B: 0.2871, Loss Recon: 0.2011, Loss P: 0.5073, Loss Comb: -8.2781
# Epoch [25/50], Loss A: 0.6109, Loss B: 0.2874, Loss Recon: 0.1925, Loss P: 0.5077, Loss Comb: -8.2829
# Epoch [26/50], Loss A: 0.6112, Loss B: 0.2875, Loss Recon: 0.1839, Loss P: 0.5082, Loss Comb: -8.2948
# Epoch [27/50], Loss A: 0.6122, Loss B: 0.2874, Loss Recon: 0.1755, Loss P: 0.5088, Loss Comb: -8.3124
# Epoch [28/50], Loss A: 0.6138, Loss B: 0.2871, Loss Recon: 0.1675, Loss P: 0.5094, Loss Comb: -8.3324
# Epoch [29/50], Loss A: 0.6155, Loss B: 0.2865, Loss Recon: 0.1598, Loss P: 0.5099, Loss Comb: -8.3506
# Epoch [30/50], Loss A: 0.6170, Loss B: 0.2855, Loss Recon: 0.1524, Loss P: 0.5102, Loss Comb: -8.3621
# Epoch [31/50], Loss A: 0.6178, Loss B: 0.2839, Loss Recon: 0.1456, Loss P: 0.5103, Loss Comb: -8.3616
# Epoch [32/50], Loss A: 0.6180, Loss B: 0.2819, Loss Recon: 0.1398, Loss P: 0.5102, Loss Comb: -8.3482
# Epoch [33/50], Loss A: 0.6177, Loss B: 0.2795, Loss Recon: 0.1349, Loss P: 0.5100, Loss Comb: -8.3265
# Epoch [34/50], Loss A: 0.6175, Loss B: 0.2770, Loss Recon: 0.1310, Loss P: 0.5095, Loss Comb: -8.3039
# Epoch [35/50], Loss A: 0.6176, Loss B: 0.2747, Loss Recon: 0.1280, Loss P: 0.5088, Loss Comb: -8.2857
# Epoch [36/50], Loss A: 0.6179, Loss B: 0.2728, Loss Recon: 0.1259, Loss P: 0.5079, Loss Comb: -8.2732
# Epoch [37/50], Loss A: 0.6183, Loss B: 0.2714, Loss Recon: 0.1244, Loss P: 0.5069, Loss Comb: -8.2655
# Epoch [38/50], Loss A: 0.6183, Loss B: 0.2706, Loss Recon: 0.1234, Loss P: 0.5058, Loss Comb: -8.2602
# Epoch [39/50], Loss A: 0.6178, Loss B: 0.2704, Loss Recon: 0.1227, Loss P: 0.5045, Loss Comb: -8.2552
# Epoch [40/50], Loss A: 0.6166, Loss B: 0.2709, Loss Recon: 0.1222, Loss P: 0.5031, Loss Comb: -8.2488
# Epoch [41/50], Loss A: 0.6147, Loss B: 0.2718, Loss Recon: 0.1219, Loss P: 0.5018, Loss Comb: -8.2411
# Epoch [42/50], Loss A: 0.6124, Loss B: 0.2731, Loss Recon: 0.1218, Loss P: 0.5005, Loss Comb: -8.2335
# Epoch [43/50], Loss A: 0.6103, Loss B: 0.2748, Loss Recon: 0.1221, Loss P: 0.4994, Loss Comb: -8.2288
# Epoch [44/50], Loss A: 0.6086, Loss B: 0.2765, Loss Recon: 0.1229, Loss P: 0.4986, Loss Comb: -8.2297
# Epoch [45/50], Loss A: 0.6078, Loss B: 0.2783, Loss Recon: 0.1243, Loss P: 0.4981, Loss Comb: -8.2382
# Epoch [46/50], Loss A: 0.6079, Loss B: 0.2800, Loss Recon: 0.1265, Loss P: 0.4978, Loss Comb: -8.2551
# Epoch [47/50], Loss A: 0.6091, Loss B: 0.2816, Loss Recon: 0.1294, Loss P: 0.4978, Loss Comb: -8.2795
# Epoch [48/50], Loss A: 0.6110, Loss B: 0.2830, Loss Recon: 0.1328, Loss P: 0.4979, Loss Comb: -8.3095
# Epoch [49/50], Loss A: 0.6133, Loss B: 0.2843, Loss Recon: 0.1363, Loss P: 0.4979, Loss Comb: -8.3418
# Epoch [50/50], Loss A: 0.6156, Loss B: 0.2854, Loss Recon: 0.1395, Loss P: 0.4978, Loss Comb: -8.3727

# %%
len(epochs_total)
# Out:
# 150

# %%
import matplotlib.cm as cm
colors = cm.viridis(np.linspace(0, 1, 4))
plt.plot(list(range(len(epochs_total))), gradient_norms_advA, color=colors[0], marker='o', label='gradient_norms_advA')
plt.plot(list(range(len(epochs_total))), gradient_norms_advB, color=colors[1], marker='o', label='gradient_norms_advB')
plt.plot(list(range(len(epochs_total))), gradient_norms_enc, color=colors[2], marker='o', label='gradient_norms_enc')
plt.plot(list(range(len(epochs_total))), gradient_norms_pred, color=colors[3], marker='o', label='gradient_norms_pred')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
import matplotlib.cm as cm
colors = cm.viridis(np.linspace(0, 1, 4))
plt.plot(list(range(len(epochs_total)))[-10:], gradient_norms_advA[-10:], color=colors[0], marker='o', label='gradient_norms_advA')
plt.plot(list(range(len(epochs_total)))[-10:], gradient_norms_advB[-10:], color=colors[1], marker='o', label='gradient_norms_advB')
plt.plot(list(range(len(epochs_total)))[-10:], gradient_norms_enc[-10:], color=colors[2], marker='o', label='gradient_norms_enc')
plt.plot(list(range(len(epochs_total)))[-10:], gradient_norms_pred[-10:], color=colors[3], marker='o', label='gradient_norms_pred')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
import matplotlib.cm as cm
colors = cm.viridis(np.linspace(0, 1, 4))
plt.plot(list(range(len(epochs_total))), gradient_norms_advA, color=colors[0], marker='o', label='gradient_norms_advA')
plt.plot(list(range(len(epochs_total))), gradient_norms_advB, color=colors[1], marker='o', label='gradient_norms_advB')
# plt.plot(list(range(len(epochs_total))), gradient_norms_enc, color=colors[2], marker='o', label='gradient_norms_enc')
plt.plot(list(range(len(epochs_total))), gradient_norms_pred, color=colors[3], marker='o', label='gradient_norms_pred')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Gradient Norm')
plt.title('Average Gradient Norm vs Epoch')
plt.grid(True)
plt.show()

# %%
# index = 0
# df = pd.DataFrame(encoder(torch.tensor(datasets[index][['X1','X2','X3','X4','A','B']].values, dtype=torch.float32)).detach().numpy(), columns=['X1', 'X2', 'X3', 'X4'])
# df_A_B_Y = datasets[index].copy()[['A', 'B', 'Y']].reset_index(drop=True)
# df = pd.concat([df, df_A_B_Y], axis=1)
# correlation_matrix = df.corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
# plt.title('Pearson Correlation Heatmap')
# plt.show()

# %%
index = 0
df_original = datasets[index].copy()

dataset = CustomDataset(df_original)
dataloader = DataLoader(dataset, batch_size=256, shuffle=False)

encoder_outputs = []
encoder.eval()
with torch.no_grad():
    for batch_X, _ in dataloader:
        output = encoder(batch_X)
        encoder_outputs.append(output)
encoder_outputs = torch.cat(encoder_outputs, dim=0)
print(encoder_outputs.shape)

encoder_outputs_np = encoder_outputs.numpy()
df = pd.DataFrame(encoder_outputs_np, columns=['X1', 'X2', 'X3', 'X4'])

df_A_B = df_original[['A', 'B', 'Y']].reset_index(drop=True)
df = pd.concat([df, df_A_B], axis=1)

correlation_matrix = df.corr()
# Out:
# torch.Size([100000, 4])

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[0].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[0].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[0].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[0].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1,2,1)
sns.heatmap(datasets[0].corr(), annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.subplot(1,2,2)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
loss_fn = nn.BCELoss()

# %%
encoder(torch.tenso)
loss_fn()

# %%
y = np.random.randint(0,2, size=10000)
y
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
y_hat = 1-y
y_hat
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import log_loss

# %%
log_loss(y,y_hat)
# Out:
# 36.043653389117146

# %%
log_loss(y,y)
# Out:
# 2.2204460492503136e-16
